# %%
import pandas as pd
import numpy as np

pd.set_option('display.max_columns', None)
pd.set_option('display.width', 1000)
pd.set_option('display.max_rows', None)
np.set_printoptions(threshold=np.inf)

# 1. Load the Datasets
# arabic.csv: The master data
df_arabic = pd.read_csv("source/arabic.csv")

# ai_output.csv: The clean structured data (drug_name, form, dose)
df_ai = pd.read_csv("source/ai.csv")

# old.csv: Loaded just for reference if needed (e.g. checking existing IDs)
df_old = pd.read_csv("source/old.csv")

# %% [markdown]
# تنظيف البيانات الأساسية

# %%
# Select only the required columns for the Database
required_columns = [
    'id', 'ProductName_EN', 'ProductName_AR', 'new_price', 
    'active_ingredients', 'image_url', 'category', 'company', 
    'form', 'units_per_pack', 'route', 'description'
]

# Create a new dataframe with ONLY these columns
df_arabic = df_arabic[required_columns].copy()

# Data Cleaning

# Clean ProductName_EN (Strip whitespace and convert to string)
df_arabic['ProductName_EN'] = df_arabic['ProductName_EN'].astype(str).str.strip()

# Clean ProductName_AR (Strip whitespace and convert to string)
df_arabic['ProductName_AR'] = df_arabic['ProductName_AR'].astype(str).str.strip()

# Clean new_price (Convert to numeric, coerce errors to NaN, fill with 0)
df_arabic['new_price'] = pd.to_numeric(df_arabic['new_price'], errors='coerce').fillna(0)

# Clean id (Ensure it is an integer)
df_arabic['id'] = pd.to_numeric(df_arabic['id'], errors='coerce').fillna(0).astype(int)

# Clean units_per_pack (Ensure it is an integer, default to 1 if missing)
df_arabic['units_per_pack'] = pd.to_numeric(df_arabic['units_per_pack'], errors='coerce').fillna(1).astype(int)

# Optional: Clean string columns to avoid 'nan' string issues in database
text_columns = ['active_ingredients', 'image_url', 'category', 'company', 'form', 'route', 'description']
for col in text_columns:
    df_arabic[col] = df_arabic[col].astype(str).str.strip().replace(['nan', 'NaN', ''], None)

print(f"Filtered DataFrame shape: {df_arabic.shape}")
# Out:
# Filtered DataFrame shape: (24853, 12)

# %%
df_arabic["form"].unique()
# Out:
# array(['tablet', 'syrup', 'spray', 'gel', 'vial', 'capsule', 'piece',
#        'cream', 'sachet', 'oral drops', 'suppository', 'tablets',
#        'syringe', 'shampoo', 'eye drops', 'effervescent', 'solution',
#        'suspension', 'vaginal douche', 'lotion', 'bottle', 'paint',
#        'facial wash', 'hair oil', 'pen', 'ampoule', 'eye ointment',
#        'ointment', None, 'nasal drops', 'mouth wash', 'serum',
#        'ear drops', 'conditioner', 'soap', 'mouth drops', 'powder', 'oil',
#        'film', 'Power', 'Cream', 'Gel', 'lozenges', 'Dro', 'patch',
#        'tabs.', 'foam', 'Cre', 'caps', 'infusion'], dtype=object)

# %%
df_old["form"].unique()
# Out:
# array(['syrup', 'tablet', 'vial', 'sachet', 'cream', 'mouth drops',
#        'tablets', 'suppository', 'capsule', 'effervescent', 'suspension',
#        'ampoule', 'gel', 'lotion', 'paint', 'facial wash', 'solution',
#        'eye drops', 'shampoo', 'hair oil', 'pen', 'eye ointment',
#        'syringe', 'ointment', 'oral drops', 'nasal drops', 'bottle',
#        'spray', 'mouth wash', 'lozenges', 'piece', 'powder', 'ear drops',
#        'vaginal douche', 'oil', 'soap', nan, 'Vial', 'tablet ',
#        'capsule ', 'suspension ', 'serum', 'Dro', 'tabs.', 'foam', 'film',
#        'conditioner', 'patch', 'caps', 'Power ', 'Cream ', 'Gel ', 'Gel',
#        'Cre', 'Cream'], dtype=object)

# %%
df_ai["form"].unique()
# Out:
# array(['tablet', 'syrup', 'gel', 'vial', 'capsule', 'Null', 'cream',
#        'soap', 'toner', 'mask', 'serum', 'sunscreen', 'sachet', 'spray',
#        'belt', 'drops', 'suppository', 'prefilled syringe',
#        'effervescent tablet', 'softgel', 'sublingual tablet',
#        'conditioner', 'lotion', 'shampoo', 'eye drop', 'suspension',
#        'infusion', 'tabs', 'tab', 'eye drops', 'mouth wash', 'supp',
#        'caps', 'ear drops', '0', 'cleanser', 'vials', 'oil', 'sachets',
#        'nasal spray', 'tablets', 'eff. gr.', 'eff salt',
#        'pd for inj./inf./oral', 'susp.', 'pd for inj./inf./inh.',
#        'drinkable amp.', 'topical solution', 'capsules', 'powder jar',
#        'powder for injection, infusion or inhalation',
#        'enteric coated tab', 'sugar coated tab', 'unit dose vial',
#        'coated tab', 'caplets', 'solution', 'chewable tablets',
#        'chewable tab', 'topical cream', 'extended release tablets',
#        'extended release tab', 'oral drops', 'sol', 'patch', 'cap',
#        'oral gel', 'topical lotion', 'patches', 'tabs.', 'supp.', 'tab.',
#        'caps.', 'vag.ovule', 'oral susp.', 'softgels', 'oil spray',
#        'massage gel', 'scored tablets', 'hand gel', 'eye contour serum',
#        'denture fixative cream', 'denture adhesive cream', 'eye gel',
#        'aqueous eye gel', 'cereal with milk', 'lentocaps', 's.r. caps',
#        'anti-dandruff hair shampoo', 'hair cream', 'hp shampoo',
#        'mc shampoo', 'pflege shampoo m.c', 'oral spray', 'toothpaste',
#        'balm', 'ophth. susp.', 'amp.', 'prolonged rel. tabs.',
#        'eye oint.', 'scalp lotion', 'prefilled pens', 'prefilled pen',
#        'amps.', 'foam', 'gummies', 'pdr', 'powder', 'packets',
#        'topical gel', 'vaginal gel', 'topical ointment',
#        'vaginal suppository', 'ointment', 'wash', 'aerosol', 'emulgel',
#        'emulsion', 'pd. for iv/im inj.', 'pd. for oral susp.', 'amp',
#        'intra-articular prefilled syringe', 'liquid caps.',
#        'hair tonic vials', 'intratracheal susp.', 'n. spray',
#        'ophth. drops', 'oint', 'milk', 'oral disinteg. tabs.',
#        'chewable tab.', 'oral dps.', 'sachtes', 'hard gelatin caps',
#        'topical spray', 'top. cream', 'inj.', 'i.m. amp.',
#        'rectal or vag. pessaries', 'ampoules',
#        'ophthalmic emulsion vials', 'vail', 'soft gelatin caps.',
#        'pd. for i.v. inf. vial', 'pd. vial for i.v. inf.',
#        'powder for i.v. vial', 'i.v. vial', 'i.v. inf.',
#        'sustained release tab', 'antiseptic foaming soln',
#        'disintegrating tablets', 'orally disintegerating tablets',
#        'pillules', 'powder solution', 'pieces', 'lyoph. pd. vial',
#        'roll on', 'soln', 'amps', 'pwd vial', 'ext rel tab', 'sc vial',
#        'sr tab', 'injection concentrate', 'susp', 'sol.', 'liquid soap',
#        'infantile supp', 'infantile supp.', 'gr. for oral susp.',
#        's.r. caps.', 'rectal supp.', 'cold gel', 'cold spray', 'ml',
#        'oral solution', 'whitening cream', 'skin cream',
#        'emollient cream', 'rectal oint', 'chewable tabs', 'dis. tabs',
#        's.r. tabs', 'e.c.tabs', 'vag.douche', 'lozenges',
#        'sublingual tab', 's.r. cap', 'scored tabs', 'ampoule', 'fluid',
#        'care', 'cartridges', 'dps', 'paste', 'ophth soln', 'facial wash',
#        'spray soln', 'gel cream', 'douche', 'ext.rel.tabs', 'baby cream',
#        'prolonged release caps', 'sublingual tabs', 'chew. tabs',
#        'amp i.m. oral', 'e. drops', 'otic susp', 'viscous eye drops',
#        'syp', 'eye oint', 'eye/ear drops', 'eye/ear oint',
#        'eye susp. drops', 'i.v.inf.', 'intr.infusion', 'i.v.infusion',
#        'i.v. inj.', 'injection', 'tooth paste', 'oral suspension',
#        'oint.', 'cap.', 'ext. rel. tabs.', 'mr tab.', 'mr tab',
#        'scored tab', 'scored tab.', 'oro-dispersible films', 'dry susp',
#        's.r. tab.', 'aerosol powder', 'dispersible tablet', 'jar',
#        'i.v. infusion', 'eye emulsion', 'granule', 'chew. tabs.',
#        'f.c. tabs.', 'f.c. tabs', 'elixir', 'soln.', 's.r. cap.',
#        'f.c.tab.', 'massage cream', 'f.c.tabs.', 'antiseptic sol.',
#        'sublingual tab.', 'vag. tabs.', 'inf.', 'jelly lubricant',
#        'orodispersible tabs.', 'dispersible tab.', 'dispersable tabs.',
#        'orodispersable tabs.', 'compresse', 'chewable pieces',
#        'oral susp', 'gingival gel', 'i.m. amps', 'i.v./i.m. amp',
#        'i.m. ampoule', 'i.m. amp', 'drink', 'orodispersible tabs',
#        'vaginal douche', 'chewable tablet', 'skin gel',
#        'powder for oral suspension', 'rectal ointment', 'm.r.caps',
#        'scrub', 'oral soln', 'shachts', 'oraldrops', 'otic drops',
#        'hair spray', 'hair lotion', 'hair mask', 'inhaler', 'syringe',
#        'transdermal patch', 'trasdermal patches', 'topical vials',
#        'dry susp.', 'dry mix for oral susp.', 's.g. caps.',
#        'disintegrating tabs.', 'syp.', 'oral spary', 's.g. cap.',
#        'i.v./s.c.vial', 'wipes', 'strips', 'hair shampoo', 'vag. wash',
#        'hair conditioning shampoo', 'hair serum', 'body wash', 'tincture',
#        'stick', 'mascara', 'tonic', 'water', 'eff tab', 'com',
#        'lipocream', 'effervescent salt', 'iud', 'foaming gel',
#        'antidandruff shampoo', 'firming cream', 'lightening cream',
#        'solvent', 'sunblock cream', 'ophth. soln.', 'vag. ovules',
#        'topical oint.', 'depot pd. sc inj.', 'iv sol.', 'dental gel',
#        'orally disintegrating tab', 'buccal bioadhesive tab',
#        'powder for solution', 'fast melt tab', 'solution cleanser',
#        'rectal oint.', 'chew.tab', 'pref. syringe', 'pref. syringes',
#        'pref. pen', 'vaginal tablets', 'bottle', 'enema',
#        'drinkable ampoules', 'inh. caps. + inhaler',
#        'i.m. injection vial', 'pwd. i.v. inf. vial', 'hair ampoule',
#        'soft capsule', 'hair conditioner', 'hair oil', 'liquid',
#        'intrauterine device', 'i.m. vial', 'dry syrup',
#        'pd. for oral susp', 'sachet for oral susp', 'vial for inf',
#        'soft cap', 'effervescent granules', 'orally disentigrating tabs',
#        'oral dis. tab', 'gel sheet', 'vial i.m/i.v', 'vial i.m/i.v.',
#        'topical oint', 'adult supp', 'i.m./i.v. vial', 'soothing cream',
#        'e.c. tab.', 'e.c. tabs.', 'i.m./i.v. amp.', 's.r. tabs.',
#        'vaginal spray', 'i.v./i.m. amp.', 'i.m./i.v. amps.',
#        'sr. f.c. tab.', 'amp. for i.v. inj.', 'eff. gr. in sachets',
#        'cr controlled release f.c. tabs.', 'i.m./s.c. amp.',
#        'eff lemon sachets', 'fruit eff. salt sachet',
#        'pineapple eff. salt sachet', 'i.m amp.', 'scored f.c. tab',
#        'prefilled syringes', 'disinteg. tabs', 'i.m./oral amp', 'pills',
#        'pd.', 'entric c. tabs.', 'scored tabs.', 'd.r. caps',
#        'd.r. caps.', 'i.v vial', 'e.c.tabs.', 'powder for i.v. inf. vial',
#        'dr. caps', 'dr. caps.', 'enteric coated tab.', 'pd for i.v. inf.',
#        's.r. capsules', 'del. rel. h.g. caps.', 'top. gel', 'ped. supp',
#        'extented release tabs', 'amps. i.v inj./inf.',
#        'soft gelatin caps', 'eff. sachet', 'eff. sachets', 'veg. caps.',
#        'pd. for oral sol.', 'chocolate pieces', 'ophth. sol', 'f.c.tabs',
#        's.r.caps', 'top.oint', 'chew. tab', 'f.c. tab',
#        'transdermal patches', 'chew. pieces', 'douch',
#        'soft chews pieces', 'sol. for intravitreal inj.', 'topical paint',
#        'dela. rel. caps', 'hand cleansing gel', 'vaginal cream',
#        'vaginal wash', 'chewble tab.', 'soap bar', 'shower gel', 'spray.',
#        'solu', 'paed.supp.', 'adult supp.', 'i.v./i.m. vial', 'inf. supp',
#        'krem', 'ampule', 'sust. rel. tabs', 'mouth refreshing spray',
#        'feminine wash', 'powder for vial', 'dispersible tab', 'v.duch',
#        's.r.caps.', 'roll', 'mouth spray', 'i.m. / i.v. amp.', 'syr',
#        'pcs', 'liquid chocolate', 'tab (chew )', 'intratracheal vial',
#        'inhalation solution', 's.g.caps.', 'massage spray',
#        'scored f.c. tab.', 'f.c. tab.', 'f.c.tab',
#        'intimate feminine wash', 'oral soln.', 'delayed release caps.',
#        'liquid vial', 'rectal cream', 'pd. in vial subcutaneous',
#        'shampoo & conditioner', 'filter bags', 'gauzes', 'toothpast',
#        'adhesive', 'vag.tabs', 'ovules', 'suppositories',
#        'granules in sachets', 'tissugel patches', 'i.v. inf. bag',
#        'oral rehydration sol.', 'inh. nebules', 'accuhaler', 'pack set',
#        'soft glatin cap', 'mouthwash', 'micro emulsion', 'sachets.',
#        'injection in prefilled syringe', 'eff tabs', 'eye susp. drop',
#        'vaginal ovules', 'eff. tabs.', 'i.v. amps.', 'sterile eye drops',
#        'i.m/i.v. vial', 'inhalation sol', 'ophthalmic sol',
#        'oral sachets', 'inj', 'tab chew', 'fast dissolving in mouth tab',
#        'sublingual tablets', 'film coated tablets', 'lotion spray',
#        'serum spray', 'bath oil', 'oily amps.', 'antidandruff treatment',
#        'eyelash & eyebrow treatment', 'men foam anti-hair loss',
#        'men treatment', 'nail treatment', 'revitalizing conditioner',
#        'anti-dandruff shampoo', 'men shampoo', 'women shampoo',
#        'women foam anti-hair loss', 'women treatment', 'caps.+inhaler',
#        'i . sol', 'inhalation anaesthetic', 'inhalation caps.+inhaler',
#        'ext. rel . tabs.', 'c. tabs.', 'syringes', 'pens',
#        'pre-filled pen', 'vial.', 'ophthalmic sol.', 'disposable syringe',
#        'kit', 'effervescent', 'eff.sachets', 'eye cream', 'foot spray',
#        'lyophilized pd. amps.', 'intertulle', 'sterile gauze dressing',
#        's.c. pref. syringe', 'i.m. pref. syrings', 's.r.tabs',
#        'vag douch', 'nail soln', 't. powder', 'vaginal douch',
#        'cream- soluble dressing', 'soluble dressing', 'shampoo & balsam',
#        'chew tablets', 'powder sachets', 'eye drops solution',
#        'ophthalmic gel', 'vegi caps.', 'vaccine vial',
#        'soft gelatin cap.', 'topical hair lotion', 'top. spray sol.',
#        'top. spray sol', 'eye dps.', 'ophthalmic soln.', 'eye ointment',
#        'vial i.v. inf.', 'oral pwd.', 'inf', 'i.v. infusion.',
#        'teething gel', 'vaginal solution', 'paint', 'chews', 'fct',
#        'eyedrops', 'gelcap', 'chew. candy',
#        'i.v./i.m. lyophilized powder vial', 'i v vial', 'im/iv amp',
#        'sugar coated tab.', 'sachet.', 'ex. rel . tab.', 'i.v amps.',
#        'pwd. sachets', 'i.v. inf. 500 ml', 'i.v. inf. 250 ml',
#        'i.v. inf. 25 ml', 'i.v. inf. 1000 ml', 'eye drops (susp.)',
#        'oral sachet', 'eff. instant gran. sachets', 'eff. tabs',
#        'chew. tab.', 'soln. for inf.', 'system (cream+wash)',
#        'facial cleansing foaming gel', 'facial gel', 'strip',
#        'vaginal pessaries', 'paed. supp.', 'pediatric supp',
#        'irrigation soln.', 'pen', 'doush', 'plaster',
#        'extended rel. tabs', 'pd', 'gummy', 'intimate cleansing gel',
#        'intimated vaginal wash', 'c.tabs', 'vaginal oint',
#        'slow release sugar coated tablet', 'intravenous infusion',
#        'concentrate', 'oral syrup', 'i.v inf', 'topical soln.',
#        'hair solution', 'p.infusion', 'p.inf.', 'inhalation caps',
#        'ped.drops', 'i.m./i.v.amp.', 'i.m.amp.', 'inhaler soln.',
#        'nail lacquer', 'teabags', 'piece', 's.c. vial', 'rectal gel',
#        'soft gelatin capsule', 'hard gelatin capsules',
#        'soft gelatin capsules', 'vaccine', 'adults gummies',
#        'vag. douche', 'facial cleanser', 'vial and prefilled syringe',
#        'food drink', 'rapid release caps.', 'i.v inf.', 'cartridge',
#        'wash.', 'skin serum', 'rehydration solution', 'eye drops sdu',
#        'i.v./i.m.vial', 'enteric coated tabs.', 'glass dropping bottle',
#        'gel vial', 'prolonged rel. tabs', 'eye drops 5 ml',
#        'orally dis. tabs', '5ml t.solution', 'cream 50 ml', 'gel 60 gm',
#        'paed. nasal sol. 10 ml', 'nasal solution',
#        'adult nasal solution 10 ml', 'adult nasal spray', 'spray 10 ml',
#        'lozenge tabs', 'amp. / vial / pref.syringe', 'implant', 'packet',
#        'iv vial', 'rectal supp', 'lyophilized amp.', 'mist',
#        'face sheet mask', 'roll-on', 'paper mask', 'sun block',
#        'pref.syringe susp. for inj s.c.', 'inh. caps.',
#        'vial for i.v. inf.', 'penfills', 'vila', 'nebuliser solution',
#        'nebuliser sol', 'spinhaler', 'extended release tab.',
#        'extended release tabs', 'i.m. prefilled syringe', 'p infusion',
#        'oil replacement', 'vial i.m./i.v.', 'balm cream',
#        'derm k concentrate', 'eye contour cream', 'urea cream',
#        'inh. soln.', 'eye contour', 'inhalation soln.',
#        'dry powder for syrup', 'i.v. amp.', 'eff sachet', 'powder vial',
#        'chew tabs', 'oral liquid', 'top cream', 'vaginal caps.',
#        'gummies 30 pcs', 'amp. inj.', '12 eff. gr. in sachets',
#        '12 eff. sachet', '10 sachets', '7 sachets', '10 oral sachets',
#        '30 tab.', '20 tab', '30 tab', '14 enteric coated tab', '30 pills',
#        '30 pieces', 'gummy multivitamin 20 pieces', 'hair tonic',
#        'vial for inf. 15 ml', '5 amps.', '20 caps.', '20 pills',
#        '30 tabs.', '30 caps.', '30 caps', 'tabs 30 filmcaoted', 'tables',
#        'jelly', 'mousse', 'oral jelly', 'rinse',
#        'oral disintegrating tablet', 'plaster sheet', 'dispenser',
#        'gel shampoo', 'SR capsule', 'pre-filled syringes', 'chewables',
#        'tas.', 'top. solution', 'i.v. infusion vial', 'scored f.c. tabs',
#        'long caps.', 'vag. tabs', 'disp. tabs.', 'pwd for oral susp.',
#        'pd. iv inf. vial', 'amp. i.v. inj.&inf.', 'oral drop',
#        'i.v. inf./bolus vial', 'tea', 'p. inf', 'sashets', 'powder sach',
#        'foaming cleanser', 'tabs chewable', 'chew./disper. tabs',
#        'dermgel', 'film forming solution', 'oro-dispersible tabs',
#        'vag douche', 'oral granules in sachets', 'cups', 'bags',
#        'flexpen', 'penfill cartridges', 'cr tab', 'oral sol.',
#        'concentrate vial', 'gel spray', 'medicated patches',
#        'orally disp. tabs', 'gel.', 'vial im iv sc',
#        'enteric coated tablet', 'dark choco. balls', 'chocolate balls',
#        'sticks', 'solutn.', 'sachets pwd. for oral susp.', 'baume',
#        'lait', 'bar', 'cream-gel', 'syurp', 'drop', 'infusine',
#        'cleansing foam', 'i.v injection', 'sach', 'inh sol', 'cr',
#        'vag cream', 'vag. tab.', 'shampoo and conditioner', 'vag ovules',
#        'chocolate', 'gel-cream', 'mist spray', 'powder for oral solution',
#        'films', 'repetabs', 'vial for injection',
#        'gastro-resistant tablets', 'suspension drops', 'pastillia',
#        'cream lotion', 'pastilles', 'nebulizer soln', 'soft gelatin cap',
#        'nasal drops', 'comprimes', 'oral sachet susp.', 'veg. caps',
#        'extended rel. caps', 'i.v. amps', 'i.v. amp', 'vial injection',
#        'chewing gummies', 'oral bottles', 'shampo', 'dispersible tabs',
#        'viscous solution', 'effervescent tabs', 'i.v. inf. vial',
#        'mr tabs', 'film coated tab', 'sach eff', 'e.c tabs.',
#        'ophthalmic soln', 'gargle & mouth wash', 'mouth&wash', 'tab loz',
#        'massage emulgel', 'metered actuations',
#        'herbal and natural oint.', 'cooling patches',
#        'orodispersible films', 'vial i.v. inf', 'injectables ampules',
#        'metered nasal spray', 'syrup+ampoule', 'coated tablets',
#        'coated caplets', 'pd. for susp.', 'gel tube', 'antiseptic soln.',
#        'solution for i.m. injection', 'pastilia', 'vag wash', 'tea bags',
#        'buccal bioadhesive tablet', 'carpules', 'granules', 'vials.',
#        'orodissolvable films', 'cap+inhaler', 'vag. gel', 'vaginal supp.',
#        'topical powder', 'liquid spray', 'powder spray',
#        'topical emulgel', 'foaming solution', 'solution rectal',
#        'inhalation capsule', 'disintegrating tabs', 'sach.', 's.r.tab.',
#        'scalp lotion 60 ml', 'topical gel 60 gm', 'foam 150 ml',
#        'hair spray 100 ml', 'topical sol. 60 ml', 'top. soln. 60 ml',
#        'mouth wash & gargle', 'chocolate tablets',
#        'mouth refreshener spray', 'topical cream 20 gm', 'vaginal ovule',
#        'vaginal ovule.', 'eye oint. 5 gm', 'susp. 60ml', 'oint 10 gm',
#        'volatile inhalation liquid 100 ml',
#        'volatile inhalation liquid 250 ml',
#        'volatile liquid inhalation 100ml',
#        'volatile liquid inhalation 250ml', 'liquid inhalation 250 ml',
#        'intrauterine delivery system', 'wash foam', 'vaginal gel wash',
#        'concentrate for i.v. infusion', 'extended release capsules',
#        'lyophilized powder vial', 'oral sol', 'ophthalmic solution',
#        'topical sol.', 'cleansing gel', 'top. gel.', 'topical gel.',
#        'chewable tabs.', 'cleansing lotion', 'creme', 'softening lotion',
#        'vaginal supp', 'vag. supp', 'skin vials',
#        'orally disintegrating tabs', 'delayed rel.tabs', 'sol. for inf.',
#        'veg caps', 'continus tab', 'sr caps', 'inhalation sol.', 'eff.',
#        'tubes', 'loops', 'aerosol spray', 'freshener', 'vag supp',
#        'cream gel', 'iv infusion vial', 'soft gels capsules', 'vial100ml',
#        'vial25ml', 'vial50ml', 'amp5ml', 'gum', 'antiseptic soln',
#        'eye susp', 'eye/ear susp', 'eye/nose drops', 'i.v. solution',
#        'top. lotion', 'fatty ointment', 'forte fatty oint', 'fatty oint.',
#        'del. rel. caps.', 'sublingual tabs.', 'coated tablet', 'lactabs',
#        's.r. tab', 'system', 'makeup remover', 'day cream', 'night cream',
#        'hand cream', 'wash & mask', 'eye dps', 'eye dpops',
#        'silicone strips', 'silicone gel', 'oral powder', 'tonic serum',
#        'porous plaster', 'oral cold drops', 'spray bottle', 'mouthsprays',
#        'vial powder', 'sugar', 'micro enemas', 'i.u.d',
#        'amp. i.m./i.v. inj.', 'carp', 'i.v. vial+prefilled syringe',
#        'insulin pen', 'penfill', 'vaginal ring', 'essence-lotion',
#        'deodorant', 'cream-mask', 'foam cleanser', 'fluid cream',
#        'roll-on mask', 'parfum', 'shower oil', 'dd light cream',
#        'dd medium cream', 'foot cream', 'lip balm', 'body cream',
#        'night face cream', 'otion', 'dental liquid cartridge',
#        'vag ovule', 'pre-filled syringe', 'ophthalmic susp.', 'quicktab',
#        'quicketab', 'ophth.solution', 'ophth. solution', 'depocaps',
#        'lactab', 's.g. caps', 's.g. cap', 'pwd. for i.v. inf.', 'ta',
#        'chewable ta', 'i.m/i.v vial', 'intraocular pref. syringe',
#        'immediate rel. tabs', 'granules for oral susp. sachets',
#        'oral granules sachets', 'nebulizer vial soln.', 'vial ss',
#        'vials . i.v. inf.', 'chew tab', 'solution for infusion',
#        'contact lens solution', 'bites', 'effervescent tablets', 'i.v.',
#        'complex', 'eye complex', 'soln. s.c. pre-filled syringe',
#        'powder for iv infusion', 'cream sun block', 'vag.spray',
#        'eff gran', 'moist wipes', 'amp. i.v inf.', 'amps. i.v inf.',
#        'amp. i.v. inf.', 'solution mouthwash', 'spray solution', 'm.w',
#        'aspirator', 'inf. vial', 'balsam', 'mouth wash and gargle',
#        'concentrate syrup', 'conc. amps', 'intravitreal implant',
#        'eff. tab.', 'gastro-resistant tab', 'effervescent tab',
#        'nebulizer soln.', 'concentrate sol.', 'iv infusion',
#        'concentrate i.v.infusion', 'extended release tabs.', 'er tabs',
#        'topical antiseptic solution', 'surgical scrub solution',
#        'vial for i.v./i.m. injection', 'i.v. ampoule', 'i.v solution',
#        'vial i.v.', 'enteric coated tabs', 'h.g.caps', 'eff.gran.',
#        'dressing', 'rectal pediatric supp.', 'paediatric supp.',
#        'controlled release tab.', 'oblong tab.', 'enteric tabs.',
#        'ophth. sol.', 'pd for i.v. inf. vial',
#        'oral rehydration solution drink', 'top. oint.', 'pre disp syrup',
#        's.r.tab', 'enemas', 'ear dps', 'ovule', 'herbs tea', 'liter',
#        'sol. vial', 'tabs. / caps.', '1000ml', '2000ml', 'ext. rel tabs.',
#        'sol 1000 ml', 'sol 2000 ml', 'oral powder in sachets',
#        'inh. caps.+inhaler', 'depotabs s.r. tab', 'chocolate pills',
#        'fluid foundation', 'peel', 'essence', 'eff. granules',
#        's.c. sol.', 'linctus', 'enema soln.', 'compact', 'ultra-fluid',
#        'unidoses', 'powder for oral soln.', 'pd. for i.v. vial',
#        'i.v.infusion 50ml', 'cream 60 gram', 'mouth wash 200 ml',
#        'eye drops 10 ml', 'oral drops 20 ml', 'chewble tab',
#        'cream 30 gm', 'vaccine s.c/ i.m inj', 'amp. i.v. inj. or inf.',
#        'vial i.v. inj. or inf.', 'gel 150 ml', 'roll-on 75 ml',
#        'spray 220 ml', 'pd. vial', 'suspension 120 ml', 'granularities',
#        'amp. i.m inj. 3ml', 'IV infusion', 'IV ampoule',
#        'concentrated infusion', 'disinteg. tabs.', 'gel massage',
#        'liquifilm ophth. sol.', 'o.d. tabs', 'h.g. caps',
#        'dual sachets powder for oral sol.', 'film',
#        'ext. release capsule', 'ext. rel. tab', 's.g caps.',
#        'oral/vaginal caps.', 'oral/vaginal caps', 'pref.syringe',
#        'sugar c.tabs.', 'pessaries', 'candy', 'vaginal delivery system',
#        'stick ointment', 'intra-ocular pref. syringe',
#        'intra-ocular pref syringe', 'oral dis.tab', 'dragee',
#        'nebulizer vial susp.', 'turbuhaler', 'turbohaler',
#        'i.v. inf. / i.m. vial', 'children supp.', 'ped. supp.',
#        'soln. i.v. inf.', 'metered dose inhaler', 'polish', 'remover',
#        'odf', 'pd. for i.v. inf.', 'vial for i.m. inj.',
#        'vial for i.v. inj.', 'i.v./i.m vial', 'i.v/i.m vial',
#        'prolonged r.tabs.', 'cartirdge', 'oral disintegrating tabs.',
#        's.c. cartridges', 'syringe.', 's.c. inj. syringe', 'paed.supp',
#        'topical foam', 'envelop', 'vial s.c/i.m injection',
#        'vial concentrate for i.v. inf.',
#        'vial lyoph. pd. for sol. for i.v. inf.', 'vial iv',
#        'vial lyoph.pd. for sol. for i.v. inf.', 'orodisp.tabs.',
#        'prolon rel caps', 'pre-filled pens', 'nasal irrigation kit',
#        'infant drops', 'pwd. oral susp sachets', 'pwd. for oral susp',
#        'pwd. for oral suspension', 'ophthalmic emulsion',
#        'exfoliating body balm', 'hair stimulating shampoo',
#        'hair stimulating conditioner', 'stretch mark cream',
#        'hair stimulating system', 'sunblock', 'sr caps.',
#        'amp. for i.m. inj.', 'amp. i.m', 'linement',
#        'pd for i.m. / i.v. inj. vial', 'infantile nasal drops',
#        'adult nasal drops', 'pediatric nasal spray', 'nasal susp.',
#        'gel body wash', 'chewable sol tab', 'i.v. inf', 'nasal gel',
#        'prolonger rel. tabs.', 'gel in sachets', 'rice',
#        's.c.prefilled syringe', 'i.m. amps.', 'female cleanser',
#        'dispersible tabs.', 'foam shampoo', 'tinted cream',
#        'tinted emulsion', 'cleansing water', 'body lotion', 'lip cream',
#        'soft gel capsules', 'hair condiotioner', 'shea butter', 'filters',
#        'filter', 'oral ampoules', 'oral liquid vial',
#        'extended release tablet', 'after shave lotion', 'collodion paint',
#        'inh. caps', 'ophthalmic drops', 's.g.caps', 's.c. amp.',
#        'vial i.m.+pref. syringe', 's.c. amps.', 'tooth gel',
#        'conc. drink (syrup)', 'tabs jar', 'spray cream',
#        'feminine cleanser', 'antiseptic', 'lotn.', 'carpule', 'sheet',
#        'band', 'rectal pediatric supp', 'elixir serum', 'face serum',
#        'capsules+inhaler', 'lozenge', 'fil.', 'cup', 'herbs', 'pack',
#        'infant supp.', 'tab (chew)', 'gargle', 'doses', 'rotadisks',
#        'ext. rel. caps', 'pd. for inh.', 'dropper',
#        'leave-in conditioner', 'oral concentrate', 'oil with serum',
#        'oral dis. tabs.', 'oral disintegrating tablets',
#        'liquid for inhalation', 'ampoules for IV/IM injection',
#        'aqua fluid', 'soln for i.v. inf', 'orodispersible sticks',
#        'powder for i.m./i.v.', 'vial i.m. i.v.', 'viscous vaginal sol.',
#        'oil bath', 'gauze dressing', 'topical aerosol (spray)',
#        'emulsion oral drops', 'bilayer tab', 'nasal vials',
#        'vial (100ml)', 'vial (50ml)', 'cream (5 sachets)',
#        'shampoo (5 sachets)', 'moist cream', 'cream (30 gm)',
#        'syrup (100ml)', 'syrup (120ml)', 'syrup (150ml)', 'patc',
#        'susp. eye drops', 'instantcondetianer', 'cream bar', 'rub',
#        'rectal micro enema', 'irrigaation soln.', 'tulle', 'vag. doushe',
#        'linimint', 'aquafluid', 'ampules', 'oro-dispersible tablets',
#        'orodispersible tab', 'solution spray', 'throat spray',
#        'sachets eff', 'i.m.amp', 'susp. amp.', 'sun screen', 'trofen',
#        'bitab', 'mouth drops', 'i.v soln', 'pwd. for i.v. inf. vial',
#        'hair stimulating solution', 'hair stimulating solutlon',
#        'hair stimulating serum', 'eye lash stimulator solutlon',
#        'anti-aging serum', 'supp infant', 'inh. caps.+handihaler',
#        'device', 'pd. oral susp.', 'oro-dispersible tabs.',
#        'topical liquid', 'depot', 'sprinkle caps.', 'ct', 'top. cr.',
#        'pd. for oral sups.', 'face cream', 'facial cleanser gel',
#        'micellar water', 'oral granules', 'facial mask', 'packs',
#        'ext. rel. tabs', 'dry suspension', 'prolonged release tab', 'gr',
#        'inj vial', 'sheets', 'soln. for i.v. inf.', 'amp. for i.v inf.',
#        'creme gel', 'cap (soft)', 'emul', '30 tabs', '6 amp', '90 tabs',
#        'mouthwash 250 ml', 'mouthwash 500 ml', '90 tab',
#        'oral spray 25 ml', 'solution 15 ml', '5 amp', '2 amp', '20 cap.',
#        'syrup 120 ml', 'lotion 100 ml', '15 filter', '10 packet',
#        '12 packet', '15 ml drops', 'nasal aspirator', 'nasal spray 50 ml',
#        '20 tips', 'lotion 120 ml', '10 supp.', '5 supp.',
#        'oral drops 15 ml', 'shampoo & conditioner & bubble bath',
#        'bubble bath', 'pen (white)', 'susp. 100ml', 'deo-cream',
#        'hydrating milk', 'eye & nasal drops', 'skin cleanser',
#        'coated tabs', 'oral pwd', 'eye gel drops', 'adult gummies',
#        'intrathecal inj', 's.c. inj', 'vaginal cleanser',
#        'powder for vaginal solution', 'vial for i.v/i.m inj.',
#        'hair oil replacement', 'collyrium', 'vial conc.',
#        'gast. resist. caps.', 'gel sensitive', 'xr tab.', 'divitab.',
#        'divitabs', 'formula', 'tetrspack', 'lyophilized vial',
#        'topical aerosol powder', 'vaginal tabs', 'vaginal tab',
#        'eye / ear oint.', 'eye / ear susp.', 'i.m. oily amp.',
#        'i.m oily amp.', 'gel fast acting', 'i.m injection',
#        'ophthalmic oint', 'pre.disp s', 'double amp',
#        'mouthwash & gargle', 'pastille', 'ophth. gel',
#        'topical spray powder', 'deoseife', 'eye dp',
#        'shampoo & body wash', 'gel cap', 'gelatin cap', 'sprinkle caps',
#        'vaginalcream', 'jel', 'vial i.m. injection', 'nail solution',
#        'drinkable ampoule', 'gelcaps', 'cream milk', 'filter tea bags',
#        'local paint', 'contr. rel. tabs.', 'eff', 'eff. granul.', 'gran',
#        'hydra lotion', 'hydrogel', 'powder milk', 'gel douch', 'caplet',
#        'dragees', 'exten. rel. tab', 'ext. rel.tabs', 'xl tab',
#        'vial and pre-filled syringe', 'subdermal',
#        'enteric coated s.r. tab', 'soln. for iv inf.', 'dividable tabs',
#        'extended rel. tab', 'cream & soap', 'soft chews', 'inh. spray',
#        'vag. supp.', 'hair vials', 'milk-gel', 'gel-balm',
#        'hair loss treatment', 'oral oint.', 'breakable tabs.',
#        'pd. conc.', 'top. soln.', 'chew.tab.', 'topical cr.', 'i.v amp',
#        'lip care', 'treatment', 'effer sachet', 'soft gel',
#        'eff gran in sachets', 'eff tablet', 'chew. coated tabs.',
#        'sublingual microlozenges', 'soft gels',
#        '(2 bottles +750ml) infusion (hospitals)', '3 tube*10 ml',
#        '3 tabs', '5 vials x', 'delayed release tablets', 'i.m vial',
#        'iv inf. vial', 'intravitreal vial', 'sunfilter',
#        'powder for injection', 'syndet', 'orodispersable tabs',
#        'powder for i.v. inf', 'delayed rel. caps',
#        'delayed rel. capsules', 'probiotic drops', 'salts',
#        'powder syrup', 'pd. oral sol.', 'pd. oral sol', 'paed.syrup',
#        'i.m inj.', 'powder for iv inf. vials', 'powder for iv inf. vial',
#        'vial for inf. inj.', 'orodispersible film', 'conc. vial inf.',
#        'i.m. / i.v. vial', 'pd. for i.m. inj.', 'pd. for i.v. inj.',
#        'gastro-resistant tabs.', 'gastro resistant tab',
#        'gastro resistant tabs.', 'tab oral dis', 'oral dis. tab.',
#        'coated tab.', 'pd. for sol. inj. vial', 'orodisperdible tabs.',
#        'granules for oral susp.', 'antiseptic solution',
#        'sanitizer spray', 'dry powder spray', 'surgical scrub',
#        'pd solutn.', 'antiseptic topical ointment', 'vag. pessaries',
#        'prolonged r. tablets', 'scalp application',
#        'vaginal douche powder', 'gynaecological solution', 'refiner',
#        'v.wash', 'condtioner', 'adults supp.', 'lyophilized i.m. ampoule',
#        'i.m./s.c. ampoule', 'prolonged release capsule',
#        'liquid conditioner', 'lightening cleanser', 'eye contour gel',
#        'eye contour pad', 'liquifilm drops', 'liquid/syrup', 'bottles',
#        'concentrate amp.', 'powder in vial i.v. inj.', 'vial pd. inj.',
#        'peices', 'antiseptic spray', 'bag', 'vaginal foam',
#        'massage oint', 'respirator soln', 'inh caps', 'modified r. tabs.',
#        'dp caps+inhaler', 'inh. caps. +inhaler device', 'sugar c. tab.',
#        'dividose tabs.', 'retard tablets', 'sterile oral soln.',
#        'compr effervesc', 'skin lotion', 'er caps', 'scored fc tabs',
#        'chew pieces', 'h.g. capsules', 'effervescent sachets',
#        'vial powder for injection', 'i.v. injection', 'suspension syrup',
#        'powder vial for infusion', 'topical aerosol spray',
#        'prolonged release tabs', 'amp. i.v.', 'lyvi', 'oily drops',
#        'oral mouth wash', 'pd for oral susp', 'inj. vial',
#        'pd for oral susp.', 'sachets pwd for oral susp', 'oral dps',
#        'oil drops', 'pd. for sol. for inj.', 'amps. i.v.',
#        'amp. for i.v/i.m inj.', 'inhalation caps.', 'opth. soln.',
#        'otic susp. drops', 'pearls', '30tab', 'gran.', 'eff. salt.',
#        'repetabs.', 'hand wash', 'facial wash foaming gel', 'comp spray',
#        'lubricating jelly', 'vag. cream', 'lubricant gel', 'beard oil',
#        'green -toothbrush', 'red hot', 'green', 'cream 15 gm',
#        'oint. 15 gm', 'cream 20 gm', 'gel 20 gm', 'oint. 20 gm',
#        'scalp lotion 30ml', 'oil 10 ml', 'oil 15 ml', '30 tablets',
#        '12 caps.', '50 tab', '20 scored tab', '30 scored tab', '10 tab',
#        '20 tablet', '10 h.g.cap', '10 h.g. cap', '15 sachets',
#        'ophth susp. 10 ml', 'oint. 30 gm', '10 tab.', '15 tab.',
#        '14 tab.', '7 tabs.', '28 tab.', '15 tabs.', '14 tabs.', '20 tabs',
#        'susp. 120ml', '10 tabs.', '14tab', 'cleanser foaming gel',
#        'expectorant syrup', 'hair tonic liquid', 'supplement syrup'],
#       dtype=object)

# %%
print(df_ai.shape)
print(df_old.shape)

df_ai["original_name"].duplicated().sum()
# Out:
# (26197, 4)
# (26201, 11)
# np.int64(0)

# %% [markdown]
# دمج الداتا فريم

# %%
df1_selected = df_ai[['original_name', 'drug_name', 'dose']]
df2_selected = df_old[['tradename', 'form']]

df_merged = pd.merge(
    df1_selected,
    df2_selected,
    left_on='original_name',
    right_on='tradename',
    how='inner'
)

display(df_merged.head(10))
display(df_merged.shape)
# Out:
#                               original_name              drug_name       dose                                 tradename     form
# 0        1 2 3 (one two three) 20 f.c.tabs.  1 2 3 (one two three)       Null        1 2 3 (one two three) 20 f.c.tabs.   tablet
# 1        1 2 3 (one two three) syrup 120 ml  1 2 3 (one two three)     120 ml        1 2 3 (one two three) syrup 120 ml    syrup
# 2                  1 2 3 extra 20 f.c. tab.            1 2 3 extra       Null                  1 2 3 extra 20 f.c. tab.   tablet
# 3                 4 wet intimate gel 100 ml         4 wet intimate     100 ml                 4 wet intimate gel 100 ml      gel
# 4  5-fluorouracil-ebewe 250mg/5ml i.v. vial   5-fluorouracil-ebewe  250 mg/ml  5-fluorouracil-ebewe 250mg/5ml i.v. vial     vial
# 5     5-ht 200 mg 60 caps. (illegal import)                   5-ht     200 mg     5-ht 200 mg 60 caps. (illegal import)  capsule
# 6                        5fu 250mg/5ml vial                    5fu  250 mg/ml                        5fu 250mg/5ml vial     vial
# 7                             900-900-900ku          900-900-900ku       Null                             900-900-900ku    piece
# 8                    Kemstical syrup 120 ml              Kemstical     120 ml                    Kemstical syrup 120 ml    syrup
# 9                             Roccatin 20mg               Roccatin      20 mg                             Roccatin 20mg   tablet
# (26198, 5)

# %% [markdown]
# النواقص

# %%
# 1. Check for items in df_old MISSING from df_ai
diff_old = pd.merge(
    df_old,
    df_ai[['original_name']],  # We only need the key column from df_ai for checking
    left_on='tradename',
    right_on='original_name',
    how='left',
    indicator=True
)

missing_from_old = diff_old[diff_old['_merge'] == 'left_only'].copy()

# 2. Check for items in df_arabic MISSING from df_ai
diff_arabic = pd.merge(
    df_arabic,
    df_ai[['original_name']],
    left_on='ProductName_EN',
    right_on='original_name',
    how='left',
    indicator=True
)

# Filter rows where the merge indicator is 'left_only'
missing_from_arabic = diff_arabic[diff_arabic['_merge'] == 'left_only'].copy()

# 3. Combine missing items into one DataFrame
names_1 = missing_from_old[['tradename']].rename(columns={'tradename': 'to_process_name'})
names_2 = missing_from_arabic[['ProductName_EN']].rename(columns={'ProductName_EN': 'to_process_name'})

# Concatenate both lists
all_missing = pd.concat([names_1, names_2])

# Drop duplicates (in case the same missing drug is in both df_old and df_arabic)
final_todo_list = all_missing.drop_duplicates().reset_index(drop=True)

print(f"Items missing in df_ai found in df_old: {len(missing_from_old)}")
print(f"Items missing in df_ai found in df_arabic: {len(missing_from_arabic)}")
print(f"Total unique items to process: {len(final_todo_list)}")

print("\n--- Sample of items to process ---")
print(final_todo_list.head())

final_todo_list.to_csv('missing.csv', index=False, encoding='utf-8')
# Out:
# Items missing in df_ai found in df_old: 3
# Items missing in df_ai found in df_arabic: 2756
# Total unique items to process: 2751
#
# --- Sample of items to process ---
#                     to_process_name
# 0                    lacto g 20 cap
# 1  optigent 0.3% eye/ear oint. 5 gm
# 2  optigent 0.3% eye/ear drops 5 ml
# 3              2hc f.c.t 20 tablets
# 4       2m whites beegu marin spray

# %% [markdown]
# required_columns = [
#     'ProductName_EN', 'ProductName_AR', 'price',
#     'active_ingredients#', 'image_url', 'category', 'company',
#     'form', 'units_per_pack', 'route', 'description'
# ]

# %% [markdown]
# التوحيد

# %%
# Rename columns in df_old to match df_arabic for easier merging
df_old_renamed = df_old.rename(columns={
    'tradename': 'ProductName_EN',      # Key for matching
    'activeingredient': 'active_ingredients',
    'new_price': 'price_old'            # Rename to avoid conflict, we'll use it to fill gaps later
})

print("✅ df_old columns renamed successfully.")
# Out:
# ✅ df_old columns renamed successfully.

# %%
# 1. Merge df_arabic with df_old_renamed
# We use 'left' to keep all arabic records.
merged_data = pd.merge(
    df_arabic,
    df_old_renamed,
    on='ProductName_EN',
    how='left', 
    suffixes=('', '_old') # Columns from df_old will have '_old' suffix if name conflicts
)

# 2. Fill missing values in df_arabic columns using data from df_old
# List of columns we want to ensure are complete
cols_to_check = ['active_ingredients', 'company', 'form', 'route']

for col in cols_to_check:
    col_old = f"{col}_old"
    # If the _old column exists, use it to fill NaNs in the main column
    if col_old in merged_data.columns:
        merged_data[col] = merged_data[col].combine_first(merged_data[col_old])

# Special handling for price (fill new_price with price_old if empty)
if 'price_old' in merged_data.columns:
    merged_data['new_price'] = merged_data['new_price'].combine_first(merged_data['price_old'])

print(f"✅ Data merged. Shape: {merged_data.shape}")
# Out:
# ✅ Data merged. Shape: (24854, 22)

# %%
# Merge with df_ai to get the clean drug_name
final_df = pd.merge(
    merged_data,
    df_ai[['original_name', 'drug_name']], 
    left_on='ProductName_EN',
    right_on='original_name',
    how='left'
)

# Overwrite ProductName_EN with the clean drug_name from df_ai
# If drug_name is NaN (no match in ai), we keep the original ProductName_EN
final_df['ProductName_EN'] = final_df['drug_name'].combine_first(final_df['ProductName_EN'])

print("✅ 'drug_name' from df_ai applied to 'ProductName_EN'.")
# Out:
# ✅ 'drug_name' from df_ai applied to 'ProductName_EN'.

# %%
# 1. Ensure column is string
final_df['active_ingredients'] = final_df['active_ingredients'].fillna('').astype(str)

# 2. Split by '+' into new columns
ingredients_split = final_df['active_ingredients'].str.split('+', expand=True)

# 3. Rename new columns dynamically (active_ingredients_1, 2, 3...)
ingredients_split.columns = [f'active_ingredients_{i+1}' for i in ingredients_split.columns]

# 4. Join these new columns back to the main dataframe
final_df = pd.concat([final_df, ingredients_split], axis=1)

print(f"✅ Active ingredients split into {len(ingredients_split.columns)} columns.")
# Out:
# ✅ Active ingredients split into 27 columns.

# %%
# 1. Define static required columns
required_columns = [
    'ProductName_EN', 'ProductName_AR', 'new_price', 
    'image_url', 'category', 'company', 
    'form', 'units_per_pack', 'route', 'description'
]

# 2. Add the dynamic active ingredient columns we just created
# We filter to make sure we only add columns that actually exist
dynamic_ing_cols = [col for col in ingredients_split.columns if col in final_df.columns]
all_target_columns = required_columns + dynamic_ing_cols

# 3. Create the final output DataFrame
df_final_output = final_df[all_target_columns].copy()

# 4. Rename 'new_price' to 'price'
df_final_output = df_final_output.rename(columns={'new_price': 'price'})

# Show results
print("--- Final Output Sample ---")
print(df_final_output.head())
# Out:
# --- Final Output Sample ---
#                 ProductName_EN               ProductName_AR  price                                    image_url                       category           company    form  units_per_pack        route                                        description active_ingredients_1        active_ingredients_2 active_ingredients_3 active_ingredients_4 active_ingredients_5 active_ingredients_6 active_ingredients_7 active_ingredients_8 active_ingredients_9 active_ingredients_10 active_ingredients_11 active_ingredients_12 active_ingredients_13 active_ingredients_14 active_ingredients_15 active_ingredients_16 active_ingredients_17 active_ingredients_18 active_ingredients_19 active_ingredients_20 active_ingredients_21 active_ingredients_22 active_ingredients_23 active_ingredients_24 active_ingredients_25 active_ingredients_26 active_ingredients_27
# 0        1 2 3 (one two three)             ون تو ثري 20 قرص   40.0    https://dwaprices.com/upload/55625338.png                     cold drugs             hikma  tablet               2   oral.solid  indication: runny noses blocked noses and sinu...      pseudoephedrine                 paracetamol     chlorpheniramine                 None                 None                 None                 None                 None                 None                  None                  None                  None                  None                  None                  None                  None                  None                  None                  None                  None                  None                  None                  None                  None                  None                  None                  None
# 1        1 2 3 (one two three)        ون تو ثري شراب 120 مل   32.0  https://dwaprices.com/upload/1518826910.jpg                     cold drugs             hikma   syrup               1  oral.liquid  as a common cold medication contains paracetam...      pseudoephedrine                 paracetamol     chlorpheniramine                 None                 None                 None                 None                 None                 None                  None                  None                  None                  None                  None                  None                  None                  None                  None                  None                  None                  None                  None                  None                  None                  None                  None                  None
# 2                  1 2 3 extra      ون تو ثري اكسترا 20 قرص   50.0  https://dwaprices.com/upload/1740153552.png                     cold drugs      hikma pharma  tablet               2   oral.solid                                               None     chlorpheniramine  paracetamol(acetaminophen)      pseudoephedrine                 None                 None                 None                 None                 None                 None                  None                  None                  None                  None                  None                  None                  None                  None                  None                  None                  None                  None                  None                  None                  None                  None                  None                  None
# 3         2hc f.c.t 20 tablets    تو اتش سي اف سي تي 20 قرص  120.0                                         None          vitamin c antioxidant          novacure  tablet               2   oral.solid                                               None       vitamin c 1 gm                        None                 None                 None                 None                 None                 None                 None                 None                  None                  None                  None                  None                  None                  None                  None                  None                  None                  None                  None                  None                  None                  None                  None                  None                  None                  None
# 4  2m whites beegu marin spray  2 ام وايتس بيجو مارين سبراي  135.0                                         None  soothing & moisturizing spray  2m whites pharma   spray               1        spray                                               None            sea water                  eucalyptus             glycerin      hyaluronic acid                 None                 None                 None                 None                 None                  None                  None                  None                  None                  None                  None                  None                  None                  None                  None                  None                  None                  None                  None                  None                  None                  None                  None

# %%
# Out:
# (24854, 37)
# (26197, 4)
